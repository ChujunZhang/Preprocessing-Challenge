# %% [markdown]
# # agenda

# %% [markdown]
# 1.load data
# 2.how many missing values
# 3.why data is missing
# 4.drop missing value
# 5.filling in missing values
# 6.sklearn imputer
# 7.clustering imputation

# %% [markdown]
# # load data

# %%
# modules
import numpy as np
import pandas as pd

#load data
nfl_data=pd.read_csv("C:\\Users\\cxz16\\kaggle 5-day challenge\\day1data\\NFL Play by Play 2009-2017 (v4).csv")
sf_permits=pd.read_csv("C:\\Users\\cxz16\\kaggle 5-day challenge\\day1data\\Building_Permits.csv")

#set seed
np.random.seed(0)
# Out:
# C:\Users\cxz16\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (25,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# C:\Users\cxz16\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
nfl_data.sample(5)
# Out:
#               Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 244485  2014-10-26  2014102607     18    3   1.0  00:39          1     939.0
# 115340  2011-11-20  2011112000     22    4   1.0  06:47          7     407.0
# 68357   2010-11-14  2010111401      8    2   NaN  00:23          1    1823.0
# 368377  2017-09-24  2017092405     24    4   1.0  08:48          9     528.0
# 384684  2017-11-05  2017110505     11    2   1.0  09:15         10    2355.0
#
#         PlayTimeDiff SideofField   ...      yacEPA  Home_WP_pre  Away_WP_pre  \
# 244485          12.0          TB   ...    1.240299     0.225647     0.774353
# 115340          44.0         OAK   ...         NaN     0.056036     0.943964
# 68357            0.0         CLE   ...         NaN     0.365307     0.634693
# 368377           8.0         CLE   ...    1.075660     0.935995     0.064005
# 384684           0.0         DEN   ...         NaN     0.928474     0.071526
#
# ...

# %%
sf_permits.sample(5)
# Out:
#        Permit Number  Permit Type  Permit Type Definition  \
# 78651   201503120624            8  otc alterations permit
# 177779  201707071220            8  otc alterations permit
# 64978        M529127            8  otc alterations permit
# 165958  201704073507            8  otc alterations permit
# 147902  201701237639            8  otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# 78651            03/12/2015  4273   029           2986                  NaN
# 177779           07/07/2017  0453  004A            950                  NaN
# 64978            10/21/2014  0478   011           1290                  NaN
# 165958           04/07/2017  6507  003A           1134                  NaN
# 147902           01/23/2017  0623   001           1755                  NaN
#
#        Street Name Street Suffix      ...        Existing Construction Type  \
# 78651         26th            St      ...                               5.0
# ...

# %% [raw]
# function used:
# pd.read_csv()
# df.sample()
# np.random.seed()

# %% [markdown]
# # how many missing values?

# %%
#missing value frequency
nfl_missing_counts=nfl_data.isnull().sum()
nfl_missing_counts[0:10]
# Out:
# Date                0
# GameID              0
# Drive               0
# qtr                 0
# down            61154
# time              224
# TimeUnder           0
# TimeSecs          224
# PlayTimeDiff      444
# SideofField       528
# dtype: int64

# %%
#missing value percentage
num_of_column=nfl_data.shape[0] #count() only count not missing value
nfl_percent=nfl_data.isnull().sum()/num_of_column
nfl_percent.sort_values(ascending=False)
# Out:
# DefTwoPoint                    0.999941
# BlockingPlayer                 0.999713
# TwoPointConv                   0.998516
# ChalReplayResult               0.991655
# RecFumbTeam                    0.989274
# RecFumbPlayer                  0.989274
# Interceptor                    0.988913
# FieldGoalDistance              0.978052
# FieldGoalResult                0.977780
# ExPointResult                  0.975202
# PenaltyType                    0.959707
# ReturnResult                   0.955265
# PuntResult                     0.945127
# Returner                       0.937933
# PenalizedPlayer                0.930621
# PenalizedTeam                  0.927643
# Tackler2                       0.878007
# RunGap                         0.785552
# RunLocation                    0.706859
# Rusher                         0.704274
# yacWPA                         0.610177
# airWPA                         0.609537
# yacEPA                         0.609530
# ...

# %%
#overall percentage
total_cells=np.product(nfl_data.shape)
total_missing_cells=nfl_data.isnull().sum().sum()
total_missing_cells/total_cells*100
# Out:
# 24.87214126835169

# %% [raw]
# function used
# isnull()
# np.product() #caculate 2*3=6
# df.shape #get how many columns and how many rows

# %% [markdown]
# # why data is missing

# %% [raw]
# two reasons:
# 1. they are not recorded
# delete or impute
# 2. they don't exist, eg. your kid's age, if no kids, age is missing
# (impute with 'doesn't exist' or just use NA)

# %% [markdown]
# # drop missing values

# %%
#first try drop rows with any na
nfl_data.dropna()
# Out:
# Empty DataFrame
# ...

# %%
#second try drop columns with any na
nfl_data.dropna(axis=1).head()
# Out:
#          Date      GameID  Drive  qtr  TimeUnder  ydstogo  ydsnet  \
# 0  2009-09-10  2009091000      1    1         15        0       0
# 1  2009-09-10  2009091000      1    1         15       10       5
# 2  2009-09-10  2009091000      1    1         15        5       2
# 3  2009-09-10  2009091000      1    1         14        8       2
# 4  2009-09-10  2009091000      1    1         14        8       2
#
#    PlayAttempted  Yards.Gained  sp   ...    Timeout_Indicator  Timeout_Team  \
# 0              1            39   0   ...                    0          None
# 1              1             5   0   ...                    0          None
# 2              1            -3   0   ...                    0          None
# 3              1             0   0   ...                    0          None
# 4              1             0   0   ...                    0          None
#
#    posteam_timeouts_pre HomeTimeouts_Remaining_Pre AwayTimeouts_Remaining_Pre  \
# ...

# %%
print("after deleting missing value cols,we have %d cols" % nfl_data.dropna(axis=1).shape[1])
# Out:
# after deleting missing value cols,we have 41 cols

# %% [raw]
# function used
# dropna() #axis=1 drop columns
# print(%d)

# %% [markdown]
# # fill in missing values

# %%
subset_nfl_data=nfl_data.loc[:,'EPA':'Season'].head()
subset_nfl_data
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474       NaN       NaN     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760       NaN       NaN     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796       NaN       NaN     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758       NaN       NaN    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295       NaN       NaN    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712       NaN       NaN    2009

# %%
# fill all na with 0
subset_nfl_data.fillna(0)
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474  0.000000  0.000000     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760  0.000000  0.000000     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796  0.000000  0.000000     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758  0.000000  0.000000    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295  0.000000  0.000000    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712  0.000000  0.000000    2009

# %%
#fill all na use the value comes directly after it (before it use 'ffill')
#then if still missing, fill with 0
#usually used in data with order, like time series
subset_nfl_data.fillna(method='bfill',axis=0).fillna(0)
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474 -1.068169  1.146076     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760  3.318841 -5.031425     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796  0.000000  0.000000     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758 -0.032244  0.036899    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295  0.106663 -0.156239    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712  0.000000  0.000000    2009

# %% [raw]
# function used
# fillna(method='bfill'/'ffill'/None,axis=0)

# %% [markdown]
# # sklearn imputation

# %% [raw]
# try different imputation method,
# try a model to find out which method has lowest MAD

# %%
subset=nfl_data.loc[:,'SideofField':'PlayType']
subset.isnull().sum()
# Out:
# SideofField         528
# yrdln               840
# yrdline100          840
# ydstogo               0
# ydsnet                0
# GoalToGo            840
# FirstDown         28811
# posteam           24992
# DefensiveTeam     24992
# desc                  2
# PlayAttempted         0
# Yards.Gained          0
# sp                    0
# Touchdown             0
# ExPointResult    397578
# TwoPointConv     407083
# DefTwoPoint      407664
# Safety                0
# Onsidekick            0
# PuntResult       385317
# PlayType              0
# dtype: int64

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
#define to score MAD
def num_MAD(X_train,X_test,Y_train,Y_test):
    model=RandomForestRegressor()
    model.fit(X_train,Y_train)
    preds=model.predict(X_test)
    return mean_absolute_error(Y_test,preds)

# %%
#only impute numeric variables
num_subset=subset.select_dtypes(exclude=['object'])
nfl_data.EPA=nfl_data.EPA.fillna(0)
#divide training and test
X_train,X_test,Y_train,Y_test=train_test_split(num_subset,nfl_data.EPA, \
                                              train_size=0.7,test_size=0.3)

# %%
#what if drop all missing columns
col_missing=[col for col in X_train.columns if X_train[col].isnull().any()]
reduce_X_train=X_train.drop(col_missing,axis=1)
reduce_X_test=X_test.drop(col_missing,axis=1)
# Out:
#         ydstogo  ydsnet  PlayAttempted  Yards.Gained  sp  Touchdown  Safety  \
# 246532        0       4              1             0   0          0       0
# 102371        7      36              1            19   0          0       0
# 313392        7      30              1             0   0          0       0
# 115102        1      67              1            13   0          0       0
# 78474        10      74              1            14   0          0       0
# 123592        0      19              1             0   0          0       0
# 209927        0       7              1             0   0          0       0
# 207867        4      76              1             0   1          0       0
# 128040        0      37              1             0   0          0       0
# 52457        10      11              1            -1   0          0       0
# 190766       10      31              1             4   0          0       0
# ...

# %%
MAD=num_MAD(reduce_X_train,reduce_X_test,Y_train,Y_test)
print("MAD when removing all missing columns is: %.10f" %MAD)
# Out:
# MAD when removing all missing columns is: 0.4950402616

# %%
#impute missing values
from sklearn.preprocessing import Imputer

# %%
my_imputer = Imputer() #default strategy is mean
imputed_X_train = my_imputer.fit_transform(X_train)
imputed_X_test = my_imputer.fit_transform(X_test)

# %%
MAD2=num_MAD(imputed_X_train,imputed_X_test,Y_train,Y_test)
print("MAD when imputing all missing columns is: %.10f" %MAD)
# Out:
# MAD when imputing all missing columns is: 0.4949259252

# %%
#label which is missing and also impute them
imputed_X_train_plus=X_train.copy()
imputed_X_test_plus=X_test.copy()
cols_with_missing = (col for col in X_train.columns 
                                 if X_train[col].isnull().any())
for col in cols_with_missing:
    imputed_X_train_plus[col + '_was_missing'] = imputed_X_train_plus[col].isnull()
    imputed_X_test_plus[col + '_was_missing'] = imputed_X_test_plus[col].isnull()
    
my_imputer = Imputer()
imputed_X_train_plus = my_imputer.fit_transform(imputed_X_train_plus)
imputed_X_test_plus = my_imputer.fit_transform(imputed_X_test_plus)

# %%
MAD3=num_MAD(imputed_X_train_plus,imputed_X_test_plus,Y_train,Y_test)
print("MAD when imputing all missing columns and showing which is imputed is: %.10f" %MAD)
# Out:
# MAD when imputing all missing columns and showing which is imputed is: 0.4950402616

# %% [markdown]
# # clustering imputation

# %%
subset=nfl_data.loc[:,'SideofField':'PlayType']
subset.isnull().sum()
# Out:
# SideofField         528
# yrdln               840
# yrdline100          840
# ydstogo               0
# ydsnet                0
# GoalToGo            840
# FirstDown         28811
# posteam           24992
# DefensiveTeam     24992
# desc                  2
# PlayAttempted         0
# Yards.Gained          0
# sp                    0
# Touchdown             0
# ExPointResult    397578
# TwoPointConv     407083
# DefTwoPoint      407664
# Safety                0
# Onsidekick            0
# PuntResult       385317
# PlayType              0
# dtype: int64

# %%
#divide training and test
X_train,X_test,Y_train,Y_test=train_test_split(num_subset,nfl_data.EPA, \
                                              train_size=0.7,test_size=0.3)

# %%
X_train_no_missing=X_train.drop(col_missing,axis=1)

# %%
#cluster, use median for that cluster to replace the missing values
from sklearn.cluster import MiniBatchKMeans
kmeans=MiniBatchKMeans()
kmeans.fit(X_train_no_missing)
X_train['cluster']=kmeans.labels_
print(pd.Series(kmeans.labels_).value_counts())
# Out:
# 3    102444
# 0     55005
# 4     46087
# 5     28874
# 7     22729
# 6     11240
# 1     10314
# 2      8688
# dtype: int64
# C:\Users\cxz16\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
X_train.head()
# Out:
#         yrdln  yrdline100  ydstogo  ydsnet  GoalToGo  FirstDown  \
# 123767   46.0        54.0       14      26       0.0        1.0
# 202805   10.0        10.0       10      86       1.0        0.0
# 308309   49.0        49.0       10      32       0.0        0.0
# 248836   32.0        32.0        0       8       0.0        0.0
# 231541   40.0        40.0       10      29       0.0        0.0
#
#         PlayAttempted  Yards.Gained  sp  Touchdown  Safety  Onsidekick  \
# 123767              1             0   0          0       0           0
# 202805              1            10   1          1       0           0
# 308309              1             0   0          0       0           0
# 248836              1             0   0          0       0           0
# 231541              1             5   0          0       0           0
#
#         cluster
# 123767        0
# 202805        5
# 308309        0
# 248836        3
# 231541        0

# %%
value_replace_missing=pd.DataFrame()
for i in col_missing:
    clean_df=X_train[['cluster',i]]
    value_replace_missing[i]=clean_df.groupby(["cluster"]).median()

# %%
for i in value_replace_missing.index:
    for col in col_missing:
        X_train.loc[(X_train['cluster']==i) & pd.isnull(X_train[col]),col]=value_replace_missing.loc[i,col]
# Out:
# C:\Users\cxz16\Anaconda3\lib\site-packages\pandas\core\indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
X_train.isnull().sum()
# Out:
# yrdln            0
# yrdline100       0
# ydstogo          0
# ydsnet           0
# GoalToGo         0
# FirstDown        0
# PlayAttempted    0
# Yards.Gained     0
# sp               0
# Touchdown        0
# Safety           0
# Onsidekick       0
# cluster          0
# dtype: int64

# %% [raw]
# Summary
# what i do in handling missing values?
# 1.values they dont exist (not missing value),
#   numeric: leave NaN
#   categorica: label 'not exist'
# 2.try to delete
#   for columns, if missing value percent is higher than 80%, delete the columns
#   for rows, may be 90%
# 3.impute categorical
#   try to find inference from other columns
#   just label 'missing'
# 4.impute numeric
#   4.1 use 0
#   4.2 use mean,median (sklearn imputer)
#   4.3 use backward, forward or both to impute (only use when sample is in order)
#   4.4 both impute mean and label missing (sklearn imputer and label missing)
#   4.5 cluster and use cluster mean
#   4.6 consider missing value column as Y, predict it
